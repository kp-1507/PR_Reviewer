# %%
# %sql
SELECT * from TEST;
select * From test;
select * from Hello3;
select * from testmerge;
select * from testmergemain;



select * from fdsfsadfsldjl;

select * from check_for_mergeconflict;
select * from checkagain;
select * from conflict102;

# %%
# %sql
select num FROM TEST;
Select result from test;
select * from checkmerge2;
select * from checkmerge3;
select * from checkmergepatch;



select * from checkingagainfkdfdl;
SELECT from num check1;
SELECT * FROM CONFLICT2;
